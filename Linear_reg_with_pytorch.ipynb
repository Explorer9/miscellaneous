# %% [markdown]
# <a href="https://colab.research.google.com/github/Explorer9/miscellaneous/blob/main/Linear_reg_with_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear regression

# %%
import torch
import sklearn
from sklearn.model_selection import train_test_split
import torch.nn
import numpy as np

# %%
np.random.seed(4)
a=np.random.rand(1000).reshape(-1,1).astype('float32')
b=np.random.rand(1000).reshape(-1,1).astype('float32')

# %%
a=np.append(a,b,axis=1)

# %%
at=torch.from_numpy(a)
bt=torch.from_numpy(b)
at.shape
# Out:
# torch.Size([1000, 3])

# %%
at.requires_grad=True
bt.requires_grad=True

# %%
x_train, x_test, y_train, y_test=train_test_split(at,bt,test_size=0.33)

# %%
class linearRegression(torch.nn.Module):
    def __init__(self, inputSize, outputSize):
        super(linearRegression, self).__init__()
        self.linear = torch.nn.Linear(inputSize, outputSize)

    def forward(self, x):
        out = self.linear(x)
        return out

# %%
inputDim = 3       # takes variable 'x' 
outputDim = 1       # takes variable 'y'
learningRate = 0.01 
epochs = 10000

# %%
model=linearRegression(inputDim,outputDim)
criterion = torch.nn.MSELoss() 
optimizer = torch.optim.SGD(model.parameters(), lr=learningRate)

# %%
for i in range(epochs):
  
 
  output=model(x_train)
  loss=criterion(y_train,output)
  optimizer.zero_grad()
  loss.backward(retain_graph=True)
  if i%100==0:
    print(loss)
  optimizer.step()
# Out:
# tensor(1.3693, grad_fn=<MseLossBackward>)
# tensor(0.0219, grad_fn=<MseLossBackward>)
# tensor(0.0127, grad_fn=<MseLossBackward>)
# tensor(0.0077, grad_fn=<MseLossBackward>)
# tensor(0.0046, grad_fn=<MseLossBackward>)
# tensor(0.0028, grad_fn=<MseLossBackward>)
# tensor(0.0017, grad_fn=<MseLossBackward>)
# tensor(0.0010, grad_fn=<MseLossBackward>)
# tensor(0.0006, grad_fn=<MseLossBackward>)
# tensor(0.0004, grad_fn=<MseLossBackward>)
# tensor(0.0002, grad_fn=<MseLossBackward>)
# tensor(0.0001, grad_fn=<MseLossBackward>)
# tensor(8.6949e-05, grad_fn=<MseLossBackward>)
# tensor(5.4030e-05, grad_fn=<MseLossBackward>)
# tensor(3.3862e-05, grad_fn=<MseLossBackward>)
# tensor(2.1442e-05, grad_fn=<MseLossBackward>)
# tensor(1.3740e-05, grad_fn=<MseLossBackward>)
# tensor(8.9267e-06, grad_fn=<MseLossBackward>)
# tensor(5.8881e-06, grad_fn=<MseLossBackward>)
# tensor(3.9483e-06, grad_fn=<MseLossBackward>)
# tensor(2.6932e-06, grad_fn=<MseLossBackward>)
# tensor(1.8691e-06, grad_fn=<MseLossBackward>)
# tensor(1.3193e-06, grad_fn=<MseLossBackward>)
# tensor(9.4608e-07, grad_fn=<MseLossBackward>)
# tensor(6.8841e-07, grad_fn=<MseLossBackward>)
# tensor(5.0740e-07, grad_fn=<MseLossBackward>)
# tensor(3.7820e-07, grad_fn=<MseLossBackward>)
# tensor(2.8457e-07, grad_fn=<MseLossBackward>)
# tensor(2.1579e-07, grad_fn=<MseLossBackward>)
# tensor(1.6469e-07, grad_fn=<MseLossBackward>)
# tensor(1.2637e-07, grad_fn=<MseLossBackward>)
# tensor(9.7355e-08, grad_fn=<MseLossBackward>)
# tensor(7.5229e-08, grad_fn=<MseLossBackward>)
# tensor(5.8305e-08, grad_fn=<MseLossBackward>)
# tensor(4.5274e-08, grad_fn=<MseLossBackward>)
# tensor(3.5204e-08, grad_fn=<MseLossBackward>)
# tensor(2.7420e-08, grad_fn=<MseLossBackward>)
# tensor(2.1383e-08, grad_fn=<MseLossBackward>)
# tensor(1.6667e-08, grad_fn=<MseLossBackward>)
# tensor(1.3020e-08, grad_fn=<MseLossBackward>)
# tensor(1.0174e-08, grad_fn=<MseLossBackward>)
# tensor(7.9327e-09, grad_fn=<MseLossBackward>)
# tensor(6.1948e-09, grad_fn=<MseLossBackward>)
# tensor(4.8575e-09, grad_fn=<MseLossBackward>)
# tensor(3.8041e-09, grad_fn=<MseLossBackward>)
# tensor(2.9744e-09, grad_fn=<MseLossBackward>)
# tensor(2.3215e-09, grad_fn=<MseLossBackward>)
# tensor(1.8077e-09, grad_fn=<MseLossBackward>)
# tensor(1.4053e-09, grad_fn=<MseLossBackward>)
# tensor(1.0955e-09, grad_fn=<MseLossBackward>)
# tensor(8.5967e-10, grad_fn=<MseLossBackward>)
# tensor(6.7735e-10, grad_fn=<MseLossBackward>)
# tensor(5.3567e-10, grad_fn=<MseLossBackward>)
# tensor(4.2404e-10, grad_fn=<MseLossBackward>)
# tensor(3.3626e-10, grad_fn=<MseLossBackward>)
# tensor(2.6783e-10, grad_fn=<MseLossBackward>)
# tensor(2.1336e-10, grad_fn=<MseLossBackward>)
# tensor(1.7003e-10, grad_fn=<MseLossBackward>)
# tensor(1.3517e-10, grad_fn=<MseLossBackward>)
# tensor(1.0772e-10, grad_fn=<MseLossBackward>)
# tensor(8.6517e-11, grad_fn=<MseLossBackward>)
# tensor(6.9500e-11, grad_fn=<MseLossBackward>)
# tensor(5.5607e-11, grad_fn=<MseLossBackward>)
# tensor(4.4337e-11, grad_fn=<MseLossBackward>)
# tensor(3.5275e-11, grad_fn=<MseLossBackward>)
# tensor(2.8192e-11, grad_fn=<MseLossBackward>)
# tensor(2.2749e-11, grad_fn=<MseLossBackward>)
# tensor(1.8550e-11, grad_fn=<MseLossBackward>)
# tensor(1.5086e-11, grad_fn=<MseLossBackward>)
# tensor(1.2208e-11, grad_fn=<MseLossBackward>)
# tensor(9.8429e-12, grad_fn=<MseLossBackward>)
# tensor(7.8962e-12, grad_fn=<MseLossBackward>)
# tensor(6.2921e-12, grad_fn=<MseLossBackward>)
# tensor(4.9427e-12, grad_fn=<MseLossBackward>)
# tensor(3.8643e-12, grad_fn=<MseLossBackward>)
# tensor(3.0379e-12, grad_fn=<MseLossBackward>)
# tensor(2.4447e-12, grad_fn=<MseLossBackward>)
# tensor(1.9875e-12, grad_fn=<MseLossBackward>)
# tensor(1.6720e-12, grad_fn=<MseLossBackward>)
# tensor(1.3865e-12, grad_fn=<MseLossBackward>)
# tensor(1.1876e-12, grad_fn=<MseLossBackward>)
# tensor(1.0461e-12, grad_fn=<MseLossBackward>)
# tensor(9.1443e-13, grad_fn=<MseLossBackward>)
# tensor(8.2689e-13, grad_fn=<MseLossBackward>)
# tensor(7.3438e-13, grad_fn=<MseLossBackward>)
# tensor(6.7245e-13, grad_fn=<MseLossBackward>)
# tensor(6.2647e-13, grad_fn=<MseLossBackward>)
# tensor(5.6865e-13, grad_fn=<MseLossBackward>)
# tensor(5.4835e-13, grad_fn=<MseLossBackward>)
# tensor(5.1876e-13, grad_fn=<MseLossBackward>)
# tensor(4.9818e-13, grad_fn=<MseLossBackward>)
# tensor(4.7921e-13, grad_fn=<MseLossBackward>)
# tensor(4.7106e-13, grad_fn=<MseLossBackward>)
# tensor(4.6625e-13, grad_fn=<MseLossBackward>)
# tensor(4.3712e-13, grad_fn=<MseLossBackward>)
# tensor(4.4045e-13, grad_fn=<MseLossBackward>)
# tensor(4.1749e-13, grad_fn=<MseLossBackward>)
# tensor(4.2629e-13, grad_fn=<MseLossBackward>)
# tensor(4.1258e-13, grad_fn=<MseLossBackward>)
# tensor(4.2310e-13, grad_fn=<MseLossBackward>)

# %%
for name, param in model.named_parameters():
  print(name, param.data)
# Out:
# linear.weight tensor([[-1.8259e-07,  8.1540e-02,  9.1846e-01]])
# linear.bias tensor([1.2020e-06])

# %%
for i in range(len(x_test)):
  print(model(x_test[i]).data,y_test[i])
# Out:
# tensor([0.8808]) tensor([0.8808], grad_fn=<SelectBackward>)
# tensor([0.9694]) tensor([0.9694], grad_fn=<SelectBackward>)
# tensor([0.0755]) tensor([0.0755], grad_fn=<SelectBackward>)
# tensor([0.0890]) tensor([0.0890], grad_fn=<SelectBackward>)
# tensor([0.5026]) tensor([0.5026], grad_fn=<SelectBackward>)
# tensor([0.4224]) tensor([0.4224], grad_fn=<SelectBackward>)
# tensor([0.4051]) tensor([0.4051], grad_fn=<SelectBackward>)
# tensor([0.9023]) tensor([0.9023], grad_fn=<SelectBackward>)
# tensor([0.1818]) tensor([0.1818], grad_fn=<SelectBackward>)
# tensor([0.6113]) tensor([0.6113], grad_fn=<SelectBackward>)
# tensor([0.7531]) tensor([0.7531], grad_fn=<SelectBackward>)
# tensor([0.7940]) tensor([0.7940], grad_fn=<SelectBackward>)
# tensor([0.2842]) tensor([0.2842], grad_fn=<SelectBackward>)
# tensor([0.9718]) tensor([0.9718], grad_fn=<SelectBackward>)
# tensor([0.8738]) tensor([0.8738], grad_fn=<SelectBackward>)
# tensor([0.0866]) tensor([0.0866], grad_fn=<SelectBackward>)
# tensor([0.2786]) tensor([0.2786], grad_fn=<SelectBackward>)
# tensor([0.9017]) tensor([0.9017], grad_fn=<SelectBackward>)
# tensor([0.9578]) tensor([0.9578], grad_fn=<SelectBackward>)
# tensor([0.1769]) tensor([0.1769], grad_fn=<SelectBackward>)
# tensor([0.1635]) tensor([0.1635], grad_fn=<SelectBackward>)
# tensor([0.7574]) tensor([0.7574], grad_fn=<SelectBackward>)
# tensor([0.7491]) tensor([0.7491], grad_fn=<SelectBackward>)
# tensor([0.6271]) tensor([0.6271], grad_fn=<SelectBackward>)
# tensor([0.1526]) tensor([0.1526], grad_fn=<SelectBackward>)
# tensor([0.1887]) tensor([0.1887], grad_fn=<SelectBackward>)
# tensor([0.9808]) tensor([0.9808], grad_fn=<SelectBackward>)
# tensor([0.7263]) tensor([0.7263], grad_fn=<SelectBackward>)
# tensor([0.0204]) tensor([0.0204], grad_fn=<SelectBackward>)
# tensor([0.2010]) tensor([0.2010], grad_fn=<SelectBackward>)
# tensor([0.5956]) tensor([0.5956], grad_fn=<SelectBackward>)
# tensor([0.4243]) tensor([0.4243], grad_fn=<SelectBackward>)
# tensor([0.7421]) tensor([0.7421], grad_fn=<SelectBackward>)
# tensor([0.0633]) tensor([0.0633], grad_fn=<SelectBackward>)
# tensor([0.6364]) tensor([0.6364], grad_fn=<SelectBackward>)
# tensor([0.9060]) tensor([0.9060], grad_fn=<SelectBackward>)
# tensor([0.5565]) tensor([0.5565], grad_fn=<SelectBackward>)
# tensor([0.3285]) tensor([0.3285], grad_fn=<SelectBackward>)
# tensor([0.2331]) tensor([0.2331], grad_fn=<SelectBackward>)
# tensor([0.5373]) tensor([0.5373], grad_fn=<SelectBackward>)
# tensor([0.0739]) tensor([0.0739], grad_fn=<SelectBackward>)
# tensor([0.1384]) tensor([0.1384], grad_fn=<SelectBackward>)
# tensor([0.9655]) tensor([0.9655], grad_fn=<SelectBackward>)
# tensor([0.1646]) tensor([0.1646], grad_fn=<SelectBackward>)
# tensor([0.0852]) tensor([0.0852], grad_fn=<SelectBackward>)
# tensor([0.1322]) tensor([0.1322], grad_fn=<SelectBackward>)
# tensor([0.0344]) tensor([0.0344], grad_fn=<SelectBackward>)
# tensor([0.6197]) tensor([0.6197], grad_fn=<SelectBackward>)
# tensor([0.2441]) tensor([0.2441], grad_fn=<SelectBackward>)
# tensor([0.1169]) tensor([0.1169], grad_fn=<SelectBackward>)
# tensor([0.9476]) tensor([0.9476], grad_fn=<SelectBackward>)
# tensor([0.4872]) tensor([0.4872], grad_fn=<SelectBackward>)
# tensor([0.8239]) tensor([0.8239], grad_fn=<SelectBackward>)
# tensor([0.8103]) tensor([0.8103], grad_fn=<SelectBackward>)
# tensor([0.6864]) tensor([0.6864], grad_fn=<SelectBackward>)
# tensor([0.5191]) tensor([0.5191], grad_fn=<SelectBackward>)
# tensor([0.6778]) tensor([0.6778], grad_fn=<SelectBackward>)
# tensor([0.1234]) tensor([0.1234], grad_fn=<SelectBackward>)
# tensor([0.7037]) tensor([0.7037], grad_fn=<SelectBackward>)
# tensor([0.2531]) tensor([0.2531], grad_fn=<SelectBackward>)
# tensor([0.4138]) tensor([0.4138], grad_fn=<SelectBackward>)
# tensor([0.6608]) tensor([0.6608], grad_fn=<SelectBackward>)
# tensor([0.1005]) tensor([0.1005], grad_fn=<SelectBackward>)
# tensor([0.7759]) tensor([0.7759], grad_fn=<SelectBackward>)
# tensor([0.6496]) tensor([0.6496], grad_fn=<SelectBackward>)
# tensor([0.4575]) tensor([0.4575], grad_fn=<SelectBackward>)
# tensor([0.9918]) tensor([0.9918], grad_fn=<SelectBackward>)
# tensor([0.1415]) tensor([0.1415], grad_fn=<SelectBackward>)
# tensor([0.0582]) tensor([0.0582], grad_fn=<SelectBackward>)
# tensor([0.5138]) tensor([0.5138], grad_fn=<SelectBackward>)
# tensor([0.1164]) tensor([0.1164], grad_fn=<SelectBackward>)
# tensor([0.4514]) tensor([0.4514], grad_fn=<SelectBackward>)
# tensor([0.1303]) tensor([0.1303], grad_fn=<SelectBackward>)
# tensor([0.2528]) tensor([0.2528], grad_fn=<SelectBackward>)
# tensor([0.4599]) tensor([0.4599], grad_fn=<SelectBackward>)
# tensor([0.8754]) tensor([0.8754], grad_fn=<SelectBackward>)
# tensor([0.7618]) tensor([0.7618], grad_fn=<SelectBackward>)
# tensor([0.2600]) tensor([0.2600], grad_fn=<SelectBackward>)
# tensor([0.0031]) tensor([0.0031], grad_fn=<SelectBackward>)
# tensor([0.3691]) tensor([0.3691], grad_fn=<SelectBackward>)
# tensor([0.7800]) tensor([0.7800], grad_fn=<SelectBackward>)
# tensor([0.8733]) tensor([0.8733], grad_fn=<SelectBackward>)
# tensor([0.2084]) tensor([0.2084], grad_fn=<SelectBackward>)
# tensor([0.9745]) tensor([0.9745], grad_fn=<SelectBackward>)
# tensor([0.1770]) tensor([0.1770], grad_fn=<SelectBackward>)
# tensor([0.3736]) tensor([0.3736], grad_fn=<SelectBackward>)
# tensor([0.6133]) tensor([0.6133], grad_fn=<SelectBackward>)
# tensor([0.5514]) tensor([0.5514], grad_fn=<SelectBackward>)
# tensor([0.5769]) tensor([0.5769], grad_fn=<SelectBackward>)
# tensor([0.8675]) tensor([0.8675], grad_fn=<SelectBackward>)
# tensor([0.6028]) tensor([0.6028], grad_fn=<SelectBackward>)
# tensor([0.4028]) tensor([0.4028], grad_fn=<SelectBackward>)
# tensor([0.6797]) tensor([0.6797], grad_fn=<SelectBackward>)
# tensor([0.7066]) tensor([0.7066], grad_fn=<SelectBackward>)
# tensor([0.7777]) tensor([0.7777], grad_fn=<SelectBackward>)
# tensor([0.5530]) tensor([0.5530], grad_fn=<SelectBackward>)
# tensor([0.8379]) tensor([0.8379], grad_fn=<SelectBackward>)
# tensor([0.5178]) tensor([0.5178], grad_fn=<SelectBackward>)
# tensor([0.6853]) tensor([0.6853], grad_fn=<SelectBackward>)
# tensor([0.9706]) tensor([0.9706], grad_fn=<SelectBackward>)
# tensor([0.3221]) tensor([0.3221], grad_fn=<SelectBackward>)
# tensor([0.3879]) tensor([0.3879], grad_fn=<SelectBackward>)
# tensor([0.4089]) tensor([0.4089], grad_fn=<SelectBackward>)
# tensor([0.7159]) tensor([0.7159], grad_fn=<SelectBackward>)
# tensor([0.9114]) tensor([0.9114], grad_fn=<SelectBackward>)
# tensor([0.7997]) tensor([0.7997], grad_fn=<SelectBackward>)
# tensor([0.2141]) tensor([0.2141], grad_fn=<SelectBackward>)
# tensor([0.4763]) tensor([0.4763], grad_fn=<SelectBackward>)
# tensor([0.6039]) tensor([0.6039], grad_fn=<SelectBackward>)
# tensor([0.6413]) tensor([0.6413], grad_fn=<SelectBackward>)
# tensor([0.0359]) tensor([0.0359], grad_fn=<SelectBackward>)
# tensor([0.7175]) tensor([0.7175], grad_fn=<SelectBackward>)
# tensor([0.4782]) tensor([0.4782], grad_fn=<SelectBackward>)
# tensor([0.7973]) tensor([0.7973], grad_fn=<SelectBackward>)
# tensor([0.4041]) tensor([0.4041], grad_fn=<SelectBackward>)
# tensor([0.0392]) tensor([0.0392], grad_fn=<SelectBackward>)
# tensor([0.8666]) tensor([0.8666], grad_fn=<SelectBackward>)
# tensor([0.1651]) tensor([0.1651], grad_fn=<SelectBackward>)
# tensor([0.7490]) tensor([0.7490], grad_fn=<SelectBackward>)
# tensor([0.1123]) tensor([0.1123], grad_fn=<SelectBackward>)
# tensor([0.3160]) tensor([0.3160], grad_fn=<SelectBackward>)
# tensor([0.5238]) tensor([0.5238], grad_fn=<SelectBackward>)
# tensor([0.5496]) tensor([0.5496], grad_fn=<SelectBackward>)
# tensor([0.2887]) tensor([0.2887], grad_fn=<SelectBackward>)
# tensor([0.4747]) tensor([0.4747], grad_fn=<SelectBackward>)
# tensor([0.0991]) tensor([0.0991], grad_fn=<SelectBackward>)
# tensor([0.4717]) tensor([0.4717], grad_fn=<SelectBackward>)
# tensor([0.3449]) tensor([0.3449], grad_fn=<SelectBackward>)
# tensor([0.5911]) tensor([0.5911], grad_fn=<SelectBackward>)
# tensor([0.8162]) tensor([0.8162], grad_fn=<SelectBackward>)
# tensor([0.4497]) tensor([0.4497], grad_fn=<SelectBackward>)
# tensor([0.8393]) tensor([0.8393], grad_fn=<SelectBackward>)
# tensor([0.8105]) tensor([0.8105], grad_fn=<SelectBackward>)
# tensor([0.1496]) tensor([0.1496], grad_fn=<SelectBackward>)
# tensor([0.0245]) tensor([0.0245], grad_fn=<SelectBackward>)
# tensor([0.8590]) tensor([0.8590], grad_fn=<SelectBackward>)
# tensor([0.5800]) tensor([0.5800], grad_fn=<SelectBackward>)
# tensor([0.9673]) tensor([0.9673], grad_fn=<SelectBackward>)
# tensor([0.1164]) tensor([0.1164], grad_fn=<SelectBackward>)
# tensor([0.5882]) tensor([0.5882], grad_fn=<SelectBackward>)
# tensor([0.8825]) tensor([0.8825], grad_fn=<SelectBackward>)
# tensor([0.6511]) tensor([0.6511], grad_fn=<SelectBackward>)
# tensor([0.7734]) tensor([0.7734], grad_fn=<SelectBackward>)
# tensor([0.1403]) tensor([0.1403], grad_fn=<SelectBackward>)
# tensor([0.9310]) tensor([0.9310], grad_fn=<SelectBackward>)
# tensor([0.4152]) tensor([0.4152], grad_fn=<SelectBackward>)
# tensor([0.7076]) tensor([0.7076], grad_fn=<SelectBackward>)
# tensor([0.2098]) tensor([0.2098], grad_fn=<SelectBackward>)
# tensor([0.4523]) tensor([0.4523], grad_fn=<SelectBackward>)
# tensor([0.9585]) tensor([0.9585], grad_fn=<SelectBackward>)
# tensor([0.0728]) tensor([0.0728], grad_fn=<SelectBackward>)
# tensor([0.1474]) tensor([0.1474], grad_fn=<SelectBackward>)
# tensor([0.6470]) tensor([0.6470], grad_fn=<SelectBackward>)
# tensor([0.8385]) tensor([0.8385], grad_fn=<SelectBackward>)
# tensor([0.0736]) tensor([0.0736], grad_fn=<SelectBackward>)
# tensor([0.0509]) tensor([0.0509], grad_fn=<SelectBackward>)
# tensor([0.7509]) tensor([0.7509], grad_fn=<SelectBackward>)
# tensor([0.9928]) tensor([0.9928], grad_fn=<SelectBackward>)
# tensor([0.8285]) tensor([0.8285], grad_fn=<SelectBackward>)
# tensor([0.4139]) tensor([0.4139], grad_fn=<SelectBackward>)
# tensor([0.4389]) tensor([0.4389], grad_fn=<SelectBackward>)
# tensor([0.2974]) tensor([0.2974], grad_fn=<SelectBackward>)
# tensor([0.7471]) tensor([0.7471], grad_fn=<SelectBackward>)
# tensor([0.9420]) tensor([0.9420], grad_fn=<SelectBackward>)
# tensor([0.8239]) tensor([0.8239], grad_fn=<SelectBackward>)
# tensor([0.7247]) tensor([0.7247], grad_fn=<SelectBackward>)
# tensor([0.1369]) tensor([0.1369], grad_fn=<SelectBackward>)
# tensor([0.7860]) tensor([0.7860], grad_fn=<SelectBackward>)
# tensor([0.7708]) tensor([0.7708], grad_fn=<SelectBackward>)
# tensor([0.1472]) tensor([0.1472], grad_fn=<SelectBackward>)
# tensor([0.2168]) tensor([0.2168], grad_fn=<SelectBackward>)
# tensor([0.9590]) tensor([0.9590], grad_fn=<SelectBackward>)
# tensor([0.4335]) tensor([0.4335], grad_fn=<SelectBackward>)
# tensor([0.8398]) tensor([0.8398], grad_fn=<SelectBackward>)
# tensor([0.7833]) tensor([0.7833], grad_fn=<SelectBackward>)
# tensor([0.5550]) tensor([0.5550], grad_fn=<SelectBackward>)
# tensor([0.7713]) tensor([0.7713], grad_fn=<SelectBackward>)
# tensor([0.8202]) tensor([0.8202], grad_fn=<SelectBackward>)
# tensor([0.0301]) tensor([0.0301], grad_fn=<SelectBackward>)
# tensor([0.3292]) tensor([0.3292], grad_fn=<SelectBackward>)
# tensor([0.7458]) tensor([0.7458], grad_fn=<SelectBackward>)
# tensor([0.4335]) tensor([0.4335], grad_fn=<SelectBackward>)
# tensor([0.5252]) tensor([0.5252], grad_fn=<SelectBackward>)
# tensor([0.7247]) tensor([0.7247], grad_fn=<SelectBackward>)
# tensor([0.9010]) tensor([0.9010], grad_fn=<SelectBackward>)
# tensor([0.5657]) tensor([0.5657], grad_fn=<SelectBackward>)
# tensor([0.5740]) tensor([0.5740], grad_fn=<SelectBackward>)
# tensor([0.2120]) tensor([0.2120], grad_fn=<SelectBackward>)
# tensor([0.3275]) tensor([0.3275], grad_fn=<SelectBackward>)
# tensor([0.6950]) tensor([0.6950], grad_fn=<SelectBackward>)
# tensor([0.8803]) tensor([0.8803], grad_fn=<SelectBackward>)
# tensor([0.9379]) tensor([0.9379], grad_fn=<SelectBackward>)
# tensor([0.6388]) tensor([0.6388], grad_fn=<SelectBackward>)
# tensor([0.6345]) tensor([0.6345], grad_fn=<SelectBackward>)
# tensor([0.4500]) tensor([0.4500], grad_fn=<SelectBackward>)
# tensor([0.0790]) tensor([0.0790], grad_fn=<SelectBackward>)
# tensor([0.5463]) tensor([0.5463], grad_fn=<SelectBackward>)
# tensor([0.2007]) tensor([0.2007], grad_fn=<SelectBackward>)
# tensor([0.2260]) tensor([0.2260], grad_fn=<SelectBackward>)
# tensor([0.8890]) tensor([0.8890], grad_fn=<SelectBackward>)
# tensor([0.8955]) tensor([0.8955], grad_fn=<SelectBackward>)
# tensor([0.4081]) tensor([0.4081], grad_fn=<SelectBackward>)
# tensor([0.1801]) tensor([0.1801], grad_fn=<SelectBackward>)
# tensor([0.1469]) tensor([0.1469], grad_fn=<SelectBackward>)
# tensor([0.2972]) tensor([0.2972], grad_fn=<SelectBackward>)
# tensor([0.9202]) tensor([0.9202], grad_fn=<SelectBackward>)
# tensor([0.3345]) tensor([0.3345], grad_fn=<SelectBackward>)
# tensor([0.7907]) tensor([0.7907], grad_fn=<SelectBackward>)
# tensor([0.9344]) tensor([0.9344], grad_fn=<SelectBackward>)
# tensor([0.8174]) tensor([0.8174], grad_fn=<SelectBackward>)
# tensor([0.9029]) tensor([0.9029], grad_fn=<SelectBackward>)
# tensor([0.3700]) tensor([0.3700], grad_fn=<SelectBackward>)
# tensor([0.7616]) tensor([0.7616], grad_fn=<SelectBackward>)
# tensor([0.1243]) tensor([0.1243], grad_fn=<SelectBackward>)
# tensor([0.5040]) tensor([0.5040], grad_fn=<SelectBackward>)
# tensor([0.1127]) tensor([0.1127], grad_fn=<SelectBackward>)
# tensor([0.6614]) tensor([0.6614], grad_fn=<SelectBackward>)
# tensor([0.6242]) tensor([0.6242], grad_fn=<SelectBackward>)
# tensor([0.9782]) tensor([0.9782], grad_fn=<SelectBackward>)
# tensor([0.9822]) tensor([0.9822], grad_fn=<SelectBackward>)
# tensor([0.4280]) tensor([0.4280], grad_fn=<SelectBackward>)
# tensor([0.8373]) tensor([0.8373], grad_fn=<SelectBackward>)
# tensor([0.9370]) tensor([0.9370], grad_fn=<SelectBackward>)
# tensor([0.1739]) tensor([0.1739], grad_fn=<SelectBackward>)
# tensor([0.2066]) tensor([0.2066], grad_fn=<SelectBackward>)
# tensor([0.0354]) tensor([0.0354], grad_fn=<SelectBackward>)
# tensor([0.1192]) tensor([0.1192], grad_fn=<SelectBackward>)
# tensor([0.8764]) tensor([0.8764], grad_fn=<SelectBackward>)
# tensor([0.8599]) tensor([0.8599], grad_fn=<SelectBackward>)
# tensor([0.3113]) tensor([0.3113], grad_fn=<SelectBackward>)
# tensor([0.0732]) tensor([0.0732], grad_fn=<SelectBackward>)
# tensor([0.0266]) tensor([0.0266], grad_fn=<SelectBackward>)
# tensor([0.4650]) tensor([0.4650], grad_fn=<SelectBackward>)
# tensor([0.2411]) tensor([0.2411], grad_fn=<SelectBackward>)
# tensor([0.3220]) tensor([0.3220], grad_fn=<SelectBackward>)
# tensor([0.2502]) tensor([0.2502], grad_fn=<SelectBackward>)
# tensor([0.0447]) tensor([0.0447], grad_fn=<SelectBackward>)
# tensor([0.8959]) tensor([0.8959], grad_fn=<SelectBackward>)
# tensor([0.6080]) tensor([0.6080], grad_fn=<SelectBackward>)
# tensor([0.2492]) tensor([0.2492], grad_fn=<SelectBackward>)
# tensor([0.3291]) tensor([0.3291], grad_fn=<SelectBackward>)
# tensor([0.7839]) tensor([0.7839], grad_fn=<SelectBackward>)
# tensor([0.7361]) tensor([0.7361], grad_fn=<SelectBackward>)
# tensor([0.4932]) tensor([0.4932], grad_fn=<SelectBackward>)
# tensor([0.2419]) tensor([0.2419], grad_fn=<SelectBackward>)
# tensor([0.6233]) tensor([0.6233], grad_fn=<SelectBackward>)
# tensor([0.5494]) tensor([0.5494], grad_fn=<SelectBackward>)
# tensor([0.0657]) tensor([0.0657], grad_fn=<SelectBackward>)
# tensor([0.2894]) tensor([0.2894], grad_fn=<SelectBackward>)
# tensor([0.1505]) tensor([0.1505], grad_fn=<SelectBackward>)
# tensor([0.2841]) tensor([0.2841], grad_fn=<SelectBackward>)
# tensor([0.5918]) tensor([0.5918], grad_fn=<SelectBackward>)
# tensor([0.9569]) tensor([0.9569], grad_fn=<SelectBackward>)
# tensor([0.7556]) tensor([0.7556], grad_fn=<SelectBackward>)
# tensor([0.3676]) tensor([0.3676], grad_fn=<SelectBackward>)
# tensor([0.4070]) tensor([0.4070], grad_fn=<SelectBackward>)
# tensor([0.7296]) tensor([0.7296], grad_fn=<SelectBackward>)
# tensor([0.5446]) tensor([0.5446], grad_fn=<SelectBackward>)
# tensor([0.0480]) tensor([0.0480], grad_fn=<SelectBackward>)
# tensor([0.2842]) tensor([0.2842], grad_fn=<SelectBackward>)
# tensor([0.6262]) tensor([0.6262], grad_fn=<SelectBackward>)
# tensor([0.3591]) tensor([0.3591], grad_fn=<SelectBackward>)
# tensor([0.7427]) tensor([0.7427], grad_fn=<SelectBackward>)
# tensor([0.3164]) tensor([0.3164], grad_fn=<SelectBackward>)
# tensor([0.8834]) tensor([0.8834], grad_fn=<SelectBackward>)
# tensor([0.0004]) tensor([0.0004], grad_fn=<SelectBackward>)
# tensor([0.4409]) tensor([0.4409], grad_fn=<SelectBackward>)
# tensor([0.3858]) tensor([0.3858], grad_fn=<SelectBackward>)
# tensor([0.5373]) tensor([0.5373], grad_fn=<SelectBackward>)
# tensor([0.8758]) tensor([0.8758], grad_fn=<SelectBackward>)
# tensor([0.5233]) tensor([0.5233], grad_fn=<SelectBackward>)
# tensor([0.5340]) tensor([0.5340], grad_fn=<SelectBackward>)
# tensor([0.7762]) tensor([0.7762], grad_fn=<SelectBackward>)
# tensor([0.7977]) tensor([0.7977], grad_fn=<SelectBackward>)
# tensor([0.1036]) tensor([0.1036], grad_fn=<SelectBackward>)
# tensor([0.8388]) tensor([0.8388], grad_fn=<SelectBackward>)
# tensor([0.6510]) tensor([0.6510], grad_fn=<SelectBackward>)
# tensor([0.1154]) tensor([0.1154], grad_fn=<SelectBackward>)
# tensor([0.8633]) tensor([0.8633], grad_fn=<SelectBackward>)
# tensor([0.9746]) tensor([0.9746], grad_fn=<SelectBackward>)
# tensor([0.8704]) tensor([0.8704], grad_fn=<SelectBackward>)
# tensor([0.9859]) tensor([0.9859], grad_fn=<SelectBackward>)
# tensor([0.5364]) tensor([0.5364], grad_fn=<SelectBackward>)
# tensor([0.2321]) tensor([0.2321], grad_fn=<SelectBackward>)
# tensor([0.2364]) tensor([0.2364], grad_fn=<SelectBackward>)
# tensor([0.5450]) tensor([0.5450], grad_fn=<SelectBackward>)
# tensor([0.1078]) tensor([0.1078], grad_fn=<SelectBackward>)
# tensor([0.0029]) tensor([0.0029], grad_fn=<SelectBackward>)
# tensor([0.6350]) tensor([0.6350], grad_fn=<SelectBackward>)
# tensor([0.3194]) tensor([0.3194], grad_fn=<SelectBackward>)
# tensor([0.4969]) tensor([0.4969], grad_fn=<SelectBackward>)
# tensor([0.6648]) tensor([0.6648], grad_fn=<SelectBackward>)
# tensor([0.9481]) tensor([0.9481], grad_fn=<SelectBackward>)
# tensor([0.5321]) tensor([0.5321], grad_fn=<SelectBackward>)
# tensor([0.5921]) tensor([0.5921], grad_fn=<SelectBackward>)
# tensor([0.1564]) tensor([0.1564], grad_fn=<SelectBackward>)
# tensor([0.2264]) tensor([0.2264], grad_fn=<SelectBackward>)
# tensor([0.3711]) tensor([0.3711], grad_fn=<SelectBackward>)
# tensor([0.6094]) tensor([0.6094], grad_fn=<SelectBackward>)
# tensor([0.5481]) tensor([0.5481], grad_fn=<SelectBackward>)
# tensor([0.5460]) tensor([0.5460], grad_fn=<SelectBackward>)
# tensor([0.0100]) tensor([0.0100], grad_fn=<SelectBackward>)
# tensor([0.8413]) tensor([0.8413], grad_fn=<SelectBackward>)
# tensor([0.2121]) tensor([0.2121], grad_fn=<SelectBackward>)
# tensor([0.4890]) tensor([0.4890], grad_fn=<SelectBackward>)
# tensor([0.0627]) tensor([0.0627], grad_fn=<SelectBackward>)
# tensor([0.8283]) tensor([0.8283], grad_fn=<SelectBackward>)
# tensor([0.0560]) tensor([0.0560], grad_fn=<SelectBackward>)
# tensor([0.5015]) tensor([0.5015], grad_fn=<SelectBackward>)
# tensor([0.2336]) tensor([0.2336], grad_fn=<SelectBackward>)
# tensor([0.1906]) tensor([0.1906], grad_fn=<SelectBackward>)
# tensor([0.9752]) tensor([0.9752], grad_fn=<SelectBackward>)
# tensor([0.1714]) tensor([0.1714], grad_fn=<SelectBackward>)
# tensor([0.1811]) tensor([0.1811], grad_fn=<SelectBackward>)
# tensor([0.4010]) tensor([0.4010], grad_fn=<SelectBackward>)
# tensor([0.1034]) tensor([0.1034], grad_fn=<SelectBackward>)
# tensor([0.5275]) tensor([0.5275], grad_fn=<SelectBackward>)
# tensor([0.3838]) tensor([0.3838], grad_fn=<SelectBackward>)
# tensor([0.9493]) tensor([0.9493], grad_fn=<SelectBackward>)
# tensor([0.8500]) tensor([0.8500], grad_fn=<SelectBackward>)
# tensor([0.9993]) tensor([0.9993], grad_fn=<SelectBackward>)
# tensor([0.0489]) tensor([0.0489], grad_fn=<SelectBackward>)
# tensor([0.2310]) tensor([0.2310], grad_fn=<SelectBackward>)
# tensor([0.8744]) tensor([0.8744], grad_fn=<SelectBackward>)
# tensor([0.7800]) tensor([0.7800], grad_fn=<SelectBackward>)
# tensor([0.1001]) tensor([0.1001], grad_fn=<SelectBackward>)
# tensor([0.2926]) tensor([0.2926], grad_fn=<SelectBackward>)
# tensor([0.2015]) tensor([0.2015], grad_fn=<SelectBackward>)
# tensor([0.4566]) tensor([0.4566], grad_fn=<SelectBackward>)
# tensor([0.8939]) tensor([0.8939], grad_fn=<SelectBackward>)
